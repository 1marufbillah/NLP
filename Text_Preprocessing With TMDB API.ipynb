# %% [markdown]
# ### Data Acquisition

# %%
import requests
import pandas as pd

def load_json_from_api(api_url):
    response = requests.get(api_url)
    if response.status_code == 200:
        json_data = response.json()
        return json_data
    else:
        print(f'Error: {response.status_code}')
        return None

api_url = 'https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page='

dfs = []

for page in range(1, 501):
    current_api_url = api_url + str(page)
    json_data = load_json_from_api(current_api_url)
    
    if json_data is not None:
        df = pd.DataFrame(json_data)
        df = df.reset_index()
        dfs.append(df)
        
combined_df = pd.concat(dfs)

filename = 'tmdb.json'
combined_df.to_json(filename, orient='records')
print(f'Combined DataFrame saved to {filename}')
# Out:
# Combined DataFrame saved to tmdb.json

# %%
tmdb = pd.read_json('tmdb.json')
tmdb
# Out:
#       index  page                                            results  \
# 0         0     1  {'adult': False, 'backdrop_path': '/tmU7GeKVyb...
# 1         1     1  {'adult': False, 'backdrop_path': '/kXfqcdQKsT...
# 2         2     1  {'adult': False, 'backdrop_path': '/kGzFbGhp99...
# 3         3     1  {'adult': False, 'backdrop_path': '/vI3aUGTuRR...
# 4         4     1  {'adult': False, 'backdrop_path': '/zb6fM1CX41...
# ...     ...   ...                                                ...
# 9995     15   500  {'adult': False, 'backdrop_path': '/qkBWIZRaeM...
# 9996     16   500  {'adult': False, 'backdrop_path': '/t2hqoksHqb...
# 9997     17   500  {'adult': False, 'backdrop_path': '/mm1JTSYpaF...
# 9998     18   500  {'adult': False, 'backdrop_path': '/yvB9wgUNyA...
# 9999     19   500  {'adult': False, 'backdrop_path': '/i19BNGN1dE...
#
#       total_pages  total_results
# 0             562          11232
# 1             562          11232
# 2             562          11232
# 3             562          11232
# 4             562          11232
# ...           ...            ...
# 9995          562          11232
# 9996          562          11232
# 9997          562          11232
# 9998          562          11232
# 9999          562          11232
#
# [10000 rows x 5 columns]

# %% [markdown]
# ### json Data Preprocess

# %%
import json
import pandas as pd

with open('data.json') as file:
    json_data = json.load(file)
    

data = []

for item in json_data:
    results = item.get('results')
    if results:
        title = results.get('title')
        overview = results.get('overview')
        genre_ids = results.get('genre_ids')
        data.append({
            'title' : title,
            'overview' : overview,
            'genre_ids' : genre_ids
        })

df = pd.DataFrame(data)
df
# Out:
#                                title  \
# 0                      The Godfather
# 1           The Shawshank Redemption
# 2              The Godfather Part II
# 3        Dilwale Dulhania Le Jayenge
# 4                   Schindler's List
# ...                              ...
# 9415                              Ma
# 9416  House at the End of the Street
# 9417                      Battleship
# 9418               Dennis the Menace
# 9419         Alvin and the Chipmunks
#
#                                                overview            genre_ids
# 0     Spanning the years 1945 to 1955, a chronicle o...             [18, 80]
# 1     Framed in the 1940s for the double murder of h...             [18, 80]
# 2     In the continuing saga of the Corleone crime f...             [18, 80]
# 3     Raj is a rich, carefree, happy-go-lucky second...      [35, 18, 10749]
# 4     The true story of how businessman Oskar Schind...      [18, 36, 10752]
# ...                                                 ...                  ...
# 9415  Sue Ann is a loner who keeps to herself in her...             [27, 53]
# 9416  A mother and daughter move to a new town and f...             [27, 53]
# 9417  When mankind beams a radio signal into space, ...    [53, 28, 12, 878]
# 9418  Mr. Wilson's ever-present annoyance comes in t...          [10751, 35]
# 9419  A struggling songwriter named Dave Seville fin...  [35, 10751, 14, 16]
#
# [9420 rows x 3 columns]

# %% [markdown]
# https://api.themoviedb.org/3/genre/movie/list?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US
#
# {"genres":[{"id":28,"name":"Action"},{"id":12,"name":"Adventure"},{"id":16,"name":"Animation"},{"id":35,"name":"Comedy"},{"id":80,"name":"Crime"},{"id":99,"name":"Documentary"},{"id":18,"name":"Drama"},{"id":10751,"name":"Family"},{"id":14,"name":"Fantasy"},{"id":36,"name":"History"},{"id":27,"name":"Horror"},{"id":10402,"name":"Music"},{"id":9648,"name":"Mystery"},{"id":10749,"name":"Romance"},{"id":878,"name":"Science Fiction"},{"id":10770,"name":"TV Movie"},{"id":53,"name":"Thriller"},{"id":10752,"name":"War"},{"id":37,"name":"Western"}]}

# %%
genre_data = {
    'genres': [
        {'id': 28, 'name': 'Action'},
        {'id': 12, 'name': 'Adventure'},
        {'id': 16, 'name': 'Animation'},
        {'id': 35, 'name': 'Comedy'},
        {'id': 80, 'name': 'Crime'},
        {'id': 99, 'name': 'Documentary'},
        {'id': 18, 'name': 'Drama'},
        {'id': 10751, 'name': 'Family'},
        {'id': 14, 'name': 'Fantasy'},
        {'id': 36, 'name': 'History'},
        {'id': 27, 'name': 'Horror'},
        {'id': 10402, 'name': 'Music'},
        {'id': 9648, 'name': 'Mystery'},
        {'id': 10749, 'name': 'Romance'},
        {'id': 878, 'name': 'Science Fiction'},
        {'id': 10770, 'name': 'TV Movie'},
        {'id': 53, 'name': 'Thriller'},
        {'id': 10752, 'name': 'War'},
        {'id': 37, 'name': 'Western'}
    ]
}

genre_mapping = {genre['id']: genre['name'] for genre in genre_data['genres']}
df['genre'] = df['genre_ids'].apply(lambda ids: [genre_mapping[id] for id in ids] if isinstance(ids, list) else [])

df.drop('genre_ids', axis=1, inplace=True)
df
# Out:
#                                title  \
# 0                      The Godfather
# 1           The Shawshank Redemption
# 2              The Godfather Part II
# 3        Dilwale Dulhania Le Jayenge
# 4                   Schindler's List
# ...                              ...
# 9415                              Ma
# 9416  House at the End of the Street
# 9417                      Battleship
# 9418               Dennis the Menace
# 9419         Alvin and the Chipmunks
#
#                                                overview  \
# 0     Spanning the years 1945 to 1955, a chronicle o...
# 1     Framed in the 1940s for the double murder of h...
# 2     In the continuing saga of the Corleone crime f...
# 3     Raj is a rich, carefree, happy-go-lucky second...
# 4     The true story of how businessman Oskar Schind...
# ...                                                 ...
# 9415  Sue Ann is a loner who keeps to herself in her...
# 9416  A mother and daughter move to a new town and f...
# 9417  When mankind beams a radio signal into space, ...
# 9418  Mr. Wilson's ever-present annoyance comes in t...
# 9419  A struggling songwriter named Dave Seville fin...
#
#                                                genre
# 0                                     [Drama, Crime]
# 1                                     [Drama, Crime]
# 2                                     [Drama, Crime]
# 3                           [Comedy, Drama, Romance]
# 4                              [Drama, History, War]
# ...                                              ...
# 9415                              [Horror, Thriller]
# 9416                              [Horror, Thriller]
# 9417  [Thriller, Action, Adventure, Science Fiction]
# 9418                                [Family, Comedy]
# 9419            [Comedy, Family, Fantasy, Animation]
#
# [9420 rows x 3 columns]

# %%
df['genre'] = df['genre'].apply(lambda genres: ', '.join(genres) if isinstance(genres, list) else '')

# %%
df = df.rename(columns={'title': 'name', 'overview': 'description'})
df
# Out:
#                                 name  \
# 0                      The Godfather
# 1           The Shawshank Redemption
# 2              The Godfather Part II
# 3        Dilwale Dulhania Le Jayenge
# 4                   Schindler's List
# ...                              ...
# 9415                              Ma
# 9416  House at the End of the Street
# 9417                      Battleship
# 9418               Dennis the Menace
# 9419         Alvin and the Chipmunks
#
#                                             description  \
# 0     Spanning the years 1945 to 1955, a chronicle o...
# 1     Framed in the 1940s for the double murder of h...
# 2     In the continuing saga of the Corleone crime f...
# 3     Raj is a rich, carefree, happy-go-lucky second...
# 4     The true story of how businessman Oskar Schind...
# ...                                                 ...
# 9415  Sue Ann is a loner who keeps to herself in her...
# 9416  A mother and daughter move to a new town and f...
# 9417  When mankind beams a radio signal into space, ...
# 9418  Mr. Wilson's ever-present annoyance comes in t...
# 9419  A struggling songwriter named Dave Seville fin...
#
#                                              genre
# 0                                     Drama, Crime
# 1                                     Drama, Crime
# 2                                     Drama, Crime
# 3                           Comedy, Drama, Romance
# 4                              Drama, History, War
# ...                                            ...
# 9415                              Horror, Thriller
# 9416                              Horror, Thriller
# 9417  Thriller, Action, Adventure, Science Fiction
# 9418                                Family, Comedy
# 9419            Comedy, Family, Fantasy, Animation
#
# [9420 rows x 3 columns]

# %% [markdown]
# ### Lowercasing

# %%
# Method 1
# df['name'] = df['name'].str.lower()
df['description'] = df['description'].str.lower()
# df['genre'] = df['genre'].str.lower()

# %%
# Method 2
# columns_to_lower = ['name','description','genre']
# for column in columns_to_lower:
#     df[column] = df[column].str.lower()

# %%
df
# Out:
#                                 name  \
# 0                      The Godfather
# 1           The Shawshank Redemption
# 2              The Godfather Part II
# 3        Dilwale Dulhania Le Jayenge
# 4                   Schindler's List
# ...                              ...
# 9415                              Ma
# 9416  House at the End of the Street
# 9417                      Battleship
# 9418               Dennis the Menace
# 9419         Alvin and the Chipmunks
#
#                                             description  \
# 0     spanning the years 1945 to 1955, a chronicle o...
# 1     framed in the 1940s for the double murder of h...
# 2     in the continuing saga of the corleone crime f...
# 3     raj is a rich, carefree, happy-go-lucky second...
# 4     the true story of how businessman oskar schind...
# ...                                                 ...
# 9415  sue ann is a loner who keeps to herself in her...
# 9416  a mother and daughter move to a new town and f...
# 9417  when mankind beams a radio signal into space, ...
# 9418  mr. wilson's ever-present annoyance comes in t...
# 9419  a struggling songwriter named dave seville fin...
#
#                                              genre
# 0                                     Drama, Crime
# 1                                     Drama, Crime
# 2                                     Drama, Crime
# 3                           Comedy, Drama, Romance
# 4                              Drama, History, War
# ...                                            ...
# 9415                              Horror, Thriller
# 9416                              Horror, Thriller
# 9417  Thriller, Action, Adventure, Science Fiction
# 9418                                Family, Comedy
# 9419            Comedy, Family, Fantasy, Animation
#
# [9420 rows x 3 columns]

# %% [markdown]
# #### check html tags

# %%
import re

def has_html_tags(text):
    pattern = '<.*?>'
    matches = re.findall(pattern, text)
    
has_html = df['description'].apply(has_html_tags)
has_html
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
#         ...
# 9415    None
# 9416    None
# 9417    None
# 9418    None
# 9419    None
# Name: description, Length: 9420, dtype: object

# %% [markdown]
# #### check urls

# %%
def has_urls(text):
    pattern = r'(https?://\s+)'
    matches = re.findall(pattern, text)
    
has_url = df['description'].apply(has_urls)
has_url
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
#         ...
# 9415    None
# 9416    None
# 9417    None
# 9418    None
# 9419    None
# Name: description, Length: 9420, dtype: object

# %% [markdown]
# #### Remove punctuation

# %%
import string

def has_punctuations(text):
    for char in text:
        if char in string.punctuation:
            return True
        return False

has_punctuation = df['description'].apply(has_punctuations)
has_punctuation
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9415    False
# 9416    False
# 9417    False
# 9418    False
# 9419    False
# Name: description, Length: 9420, dtype: object

# %%
def remove_punctuation(text):
    for char in string.punctuation:
        text = text.replace(char, '')
    return text

df['description'] = df['description'].apply(remove_punctuation)
has_punctuation = df['description'].apply(lambda x: bool(re.search('['+string.punctuation+']', x)))
has_punctuation
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9415    False
# 9416    False
# 9417    False
# 9418    False
# 9419    False
# Name: description, Length: 9420, dtype: bool

# %%
df['description']
# Out:
# 0       spanning the years 1945 to 1955 a chronicle of...
# 1       framed in the 1940s for the double murder of h...
# 2       in the continuing saga of the corleone crime f...
# 3       raj is a rich carefree happygolucky second gen...
# 4       the true story of how businessman oskar schind...
#                               ...
# 9415    sue ann is a loner who keeps to herself in her...
# 9416    a mother and daughter move to a new town and f...
# 9417    when mankind beams a radio signal into space a...
# 9418    mr wilsons everpresent annoyance comes in the ...
# 9419    a struggling songwriter named dave seville fin...
# Name: description, Length: 9420, dtype: object

# %% [markdown]
# #### Spell Correction

# %%
import pandas as pd
from textblob import TextBlob
import time

start_time = time.time()
df['description'] = pd.DataFrame(df['description'])

def check_spelling_mistakes(text):
    blob = TextBlob(text)
    return str(blob.correct())

df['description'] = df['description'].apply(check_spelling_mistakes)
df

end_time = time.time()

total_time = end_time - start_time
print(f'Total run time: {total_time} seconds')
# around 38  minitues Apple M2 2023
# Out:
# Total run time: 2335.492346763611 seconds

# %%
df
# Out:
#                                 name  \
# 0                      The Godfather
# 1           The Shawshank Redemption
# 2              The Godfather Part II
# 3        Dilwale Dulhania Le Jayenge
# 4                   Schindler's List
# ...                              ...
# 9415                              Ma
# 9416  House at the End of the Street
# 9417                      Battleship
# 9418               Dennis the Menace
# 9419         Alvin and the Chipmunks
#
#                                             description  \
# 0     spanning the years 1945 to 1955 a chronicle of...
# 1     framed in the 1940s for the double murder of h...
# 2     in the continuing sage of the corleone crime f...
# 3     ran is a rich carefree happygolucky second gen...
# 4     the true story of how businessman oscar schind...
# ...                                                 ...
# 9415  sue ann is a longer who keeps to herself in he...
# 9416  a mother and daughter move to a new town and f...
# 9417  when mankind beams a radio signal into space a...
# 9418  mr wilson everpresent annoyance comes in the f...
# 9419  a struggling songwriter named dave seville fin...
#
#                                              genre
# 0                                     Drama, Crime
# 1                                     Drama, Crime
# 2                                     Drama, Crime
# 3                           Comedy, Drama, Romance
# 4                              Drama, History, War
# ...                                            ...
# 9415                              Horror, Thriller
# 9416                              Horror, Thriller
# 9417  Thriller, Action, Adventure, Science Fiction
# 9418                                Family, Comedy
# 9419            Comedy, Family, Fantasy, Animation
#
# [9420 rows x 3 columns]

# %% [markdown]
# #### Remove stopwords

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords

# nltk.download('stopwords')

stop_words = set(stopwords.words('english'))

def check_stop_words(text):
    words = text.split()
    stop_word_found = [word for word in words if word.lower() in stop_words]
    return bool(stop_word_found)

df['Stop_Words_Present'] = df['description'].apply(check_stop_words)

# %%
df.drop('Stop_Words_Present', axis=1, inplace=True)

# %%
def remove_stop_words(text):
    words = text.split()
    filtered_words = [word for word in words if word.lower() not in stop_words]
    return ' '.join(filtered_words)
df['description'] = df['description'].apply(remove_stop_words)

# %%
df
# Out:
#                                 name  \
# 0                      The Godfather
# 1           The Shawshank Redemption
# 2              The Godfather Part II
# 3        Dilwale Dulhania Le Jayenge
# 4                   Schindler's List
# ...                              ...
# 9415                              Ma
# 9416  House at the End of the Street
# 9417                      Battleship
# 9418               Dennis the Menace
# 9419         Alvin and the Chipmunks
#
#                                             description  \
# 0     spanning years 1945 1955 chronicle sectional i...
# 1     framed 1940s double murder wife lover standing...
# 2     continuing sage corleone crime family young ve...
# 3     ran rich carefree happygolucky second generati...
# 4     true story businessman oscar schindler saved t...
# ...                                                 ...
# 9415  sue ann longer keeps quiet ohio town one day a...
# 9416  mother daughter move new town find living next...
# 9417  mankind beams radio signal space reply comes ‘...
# 9418  mr wilson everpresent annoyance comes form one...
# 9419  struggling songwriter named dave seville finds...
#
#                                              genre
# 0                                     Drama, Crime
# 1                                     Drama, Crime
# 2                                     Drama, Crime
# 3                           Comedy, Drama, Romance
# 4                              Drama, History, War
# ...                                            ...
# 9415                              Horror, Thriller
# 9416                              Horror, Thriller
# 9417  Thriller, Action, Adventure, Science Fiction
# 9418                                Family, Comedy
# 9419            Comedy, Family, Fantasy, Animation
#
# [9420 rows x 3 columns]

# %% [markdown]
# #### Remove Emoji

# %%
import re
import pandas as pd

def remove_emojis(text):
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               u"\U00002500-\U00002BEF"  # chinese char
                               u"\U00002702-\U000027B0"
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               u"\U0001f926-\U0001f937"
                               u"\U00010000-\U0010ffff"
                               u"\u2640-\u2642"
                               u"\u2600-\u2B55"
                               u"\u200d"
                               u"\u23cf"
                               u"\u23e9"
                               u"\u231a"
                               u"\ufe0f"  # dingbats
                               u"\u3030"
                               "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

df['description'] = df['description'].apply(remove_emojis)

# %% [markdown]
# #### Tokenizing

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
nltk.download('punkt')

def tokenize(text):
    tokens = word_tokenize(text)
    return tokens

df['Tokens'] = df['description'].apply(tokenize)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/marufbillah/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df['Tokens']
# Out:
# 0       [spanning, years, 1945, 1955, chronicle, secti...
# 1       [framed, 1940s, double, murder, wife, lover, s...
# 2       [continuing, sage, corleone, crime, family, yo...
# 3       [ran, rich, carefree, happygolucky, second, ge...
# 4       [true, story, businessman, oscar, schindler, s...
#                               ...
# 9415    [sue, ann, longer, keeps, quiet, ohio, town, o...
# 9416    [mother, daughter, move, new, town, find, livi...
# 9417    [mankind, beams, radio, signal, space, reply, ...
# 9418    [mr, wilson, everpresent, annoyance, comes, fo...
# 9419    [struggling, songwriter, named, dave, seville,...
# Name: Tokens, Length: 9420, dtype: object

# %% [markdown]
# #### Stemming

# %%
from nltk.stem import PorterStemmer, SnowballStemmer, LancasterStemmer

porter = PorterStemmer()
snowball = SnowballStemmer('english')
lancaster = LancasterStemmer()

def porter_stem(text):
    porter_stammed = [porter.stem(word) for word in text]
    return porter_stammed

df['Porter_Stemmed'] = df['description'].apply(porter_stem)

# %%
df['Porter_Stemmed']
# Out:
# 0       [s, p, a, n, n, i, n, g,  , y, e, a, r, s,  , ...
# 1       [f, r, a, m, e, d,  , 1, 9, 4, 0, s,  , d, o, ...
# 2       [c, o, n, t, i, n, u, i, n, g,  , s, a, g, e, ...
# 3       [r, a, n,  , r, i, c, h,  , c, a, r, e, f, r, ...
# 4       [t, r, u, e,  , s, t, o, r, y,  , b, u, s, i, ...
#                               ...
# 9415    [s, u, e,  , a, n, n,  , l, o, n, g, e, r,  , ...
# 9416    [m, o, t, h, e, r,  , d, a, u, g, h, t, e, r, ...
# 9417    [m, a, n, k, i, n, d,  , b, e, a, m, s,  , r, ...
# 9418    [m, r,  , w, i, l, s, o, n,  , e, v, e, r, p, ...
# 9419    [s, t, r, u, g, g, l, i, n, g,  , s, o, n, g, ...
# Name: Porter_Stemmed, Length: 9420, dtype: object

# %% [markdown]
# #### Lemmatization

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
nltk.download('omw-1.4')

lemmatizer = WordNetLemmatizer()

def lemmatize(text):
    tokens = word_tokenize(text)
    lemmatized = [lemmatizer.lemmatize(word) for word in tokens]
    return ' '.join(lemmatized)

df['Lemmatized'] = df['description'].apply(lemmatize)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/marufbillah/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/marufbillah/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
df['Lemmatized']
# Out:
# 0       spanning year 1945 1955 chronicle sectional it...
# 1       framed 1940s double murder wife lover standing...
# 2       continuing sage corleone crime family young ve...
# 3       ran rich carefree happygolucky second generati...
# 4       true story businessman oscar schindler saved t...
#                               ...
# 9415    sue ann longer keep quiet ohio town one day as...
# 9416    mother daughter move new town find living next...
# 9417    mankind beam radio signal space reply come ‘ p...
# 9418    mr wilson everpresent annoyance come form one ...
# 9419    struggling songwriter named dave seville find ...
# Name: Lemmatized, Length: 9420, dtype: object

# %%
df
# Out:
#                                 name  \
# 0                      The Godfather
# 1           The Shawshank Redemption
# 2              The Godfather Part II
# 3        Dilwale Dulhania Le Jayenge
# 4                   Schindler's List
# ...                              ...
# 9415                              Ma
# 9416  House at the End of the Street
# 9417                      Battleship
# 9418               Dennis the Menace
# 9419         Alvin and the Chipmunks
#
#                                             description  \
# 0     spanning years 1945 1955 chronicle sectional i...
# 1     framed 1940s double murder wife lover standing...
# 2     continuing sage corleone crime family young ve...
# 3     ran rich carefree happygolucky second generati...
# 4     true story businessman oscar schindler saved t...
# ...                                                 ...
# 9415  sue ann longer keeps quiet ohio town one day a...
# 9416  mother daughter move new town find living next...
# 9417  mankind beams radio signal space reply comes ‘...
# 9418  mr wilson everpresent annoyance comes form one...
# 9419  struggling songwriter named dave seville finds...
#
#                                              genre  \
# 0                                     Drama, Crime
# 1                                     Drama, Crime
# 2                                     Drama, Crime
# 3                           Comedy, Drama, Romance
# 4                              Drama, History, War
# ...                                            ...
# 9415                              Horror, Thriller
# 9416                              Horror, Thriller
# 9417  Thriller, Action, Adventure, Science Fiction
# 9418                                Family, Comedy
# 9419            Comedy, Family, Fantasy, Animation
#
#                                                  Tokens  \
# 0     [spanning, years, 1945, 1955, chronicle, secti...
# 1     [framed, 1940s, double, murder, wife, lover, s...
# 2     [continuing, sage, corleone, crime, family, yo...
# 3     [ran, rich, carefree, happygolucky, second, ge...
# 4     [true, story, businessman, oscar, schindler, s...
# ...                                                 ...
# 9415  [sue, ann, longer, keeps, quiet, ohio, town, o...
# 9416  [mother, daughter, move, new, town, find, livi...
# 9417  [mankind, beams, radio, signal, space, reply, ...
# 9418  [mr, wilson, everpresent, annoyance, comes, fo...
# 9419  [struggling, songwriter, named, dave, seville,...
#
#                                          Porter_Stemmed  \
# 0     [s, p, a, n, n, i, n, g,  , y, e, a, r, s,  , ...
# 1     [f, r, a, m, e, d,  , 1, 9, 4, 0, s,  , d, o, ...
# 2     [c, o, n, t, i, n, u, i, n, g,  , s, a, g, e, ...
# 3     [r, a, n,  , r, i, c, h,  , c, a, r, e, f, r, ...
# 4     [t, r, u, e,  , s, t, o, r, y,  , b, u, s, i, ...
# ...                                                 ...
# 9415  [s, u, e,  , a, n, n,  , l, o, n, g, e, r,  , ...
# 9416  [m, o, t, h, e, r,  , d, a, u, g, h, t, e, r, ...
# 9417  [m, a, n, k, i, n, d,  , b, e, a, m, s,  , r, ...
# 9418  [m, r,  , w, i, l, s, o, n,  , e, v, e, r, p, ...
# 9419  [s, t, r, u, g, g, l, i, n, g,  , s, o, n, g, ...
#
#                                              Lemmatized
# 0     spanning year 1945 1955 chronicle sectional it...
# 1     framed 1940s double murder wife lover standing...
# 2     continuing sage corleone crime family young ve...
# 3     ran rich carefree happygolucky second generati...
# 4     true story businessman oscar schindler saved t...
# ...                                                 ...
# 9415  sue ann longer keep quiet ohio town one day as...
# 9416  mother daughter move new town find living next...
# 9417  mankind beam radio signal space reply come ‘ p...
# 9418  mr wilson everpresent annoyance come form one ...
# 9419  struggling songwriter named dave seville find ...
#
# [9420 rows x 6 columns]
